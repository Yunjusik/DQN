# %%
import numpy as np

# %%
arr  = np.array(5)
arr.shape
###0차원인 스칼라 5값만 넣었으므로, shape이 없음
# Out:
# ()

# %%
arr.ndim
# Out:
# 0

# %% [markdown]
# ## 1차원
# #### 스칼라는 0차원인데, 안에 리스트를 하나라도 씌우게되면 1차원이됨

# %%
arr2 = np.array ([5])
arr2.shape
#여기서 1은 값이 1개라는뜻
# Out:
# (1,)

# %%
arr2.ndim
# 1차원
# Out:
# 1

# %%
arr3 = np.array ([1,2,3])
arr3.shape
# Out:
# (3,)

# %%
arr3.ndim
# Out:
# 1

# %% [markdown]
# # 2차원
# ### 괄호를 두개치면 2차원

# %%
arr = np.array([[1,2,3]])
arr.shape
# 차원이 두개가 있고, 각 차원마다 값이 3개씩 있음.
#1x3
# Out:
# (1, 3)

# %%
arr = np.array([[1,2,3],[4,5,6],[3,6,1]])
print(arr)
print(arr.shape)   
# 1차원이 3개 모인 3 by 3 행렬
print(arr.ndim)
#2차원
# Out:
# [[1 2 3]
#  [4 5 6]
#  [3 6 1]]
# (3, 3)
# 2

# %% [markdown]
# # 다차원

# %%
arr=np.array([[[[1,5,3],[1,2,3],[1,2,3]],[[1,2,3],[1,2,3],[1,2,3]],[[1,2,3],[1,2,3],[1,2,3]]],[[[1,2,3],[1,2,3],[1,2,3]],[[1,2,3],[1,2,3],[1,2,3]],[[1,2,3],[1,2,3],[1,2,3]]]])
arr.shape

# 3x3이 3개있는게 또 2번있는 모양.
# Out:
# (2, 3, 3, 3)

# %%
arr.ndim 
#4차원
# Out:
# 4

# %%
#모양확인, 3x3행렬이 3개가있고,그게다시 두번있는것.
arr
# Out:
# array([[[[1, 5, 3],
#          [1, 2, 3],
#          [1, 2, 3]],
#
#         [[1, 2, 3],
#          [1, 2, 3],
#          [1, 2, 3]],
#
#         [[1, 2, 3],
#          [1, 2, 3],
#          [1, 2, 3]]],
#
#
#        [[[1, 2, 3],
#          [1, 2, 3],
#          [1, 2, 3]],
#
#         [[1, 2, 3],
#          [1, 2, 3],
#          [1, 2, 3]],
#
#         [[1, 2, 3],
#          [1, 2, 3],
#          [1, 2, 3]]]])
